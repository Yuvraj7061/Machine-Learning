# %%
pip install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df['area'], df['price'] , color = 'red' , marker ='+')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Per Capita Income in Canada Over Years')
plt.show()

# %%
plt.scatter(df['area'], df['price'] , color = 'red' , marker ='+')
plt.xlabel('Area' ,  fontsize = 20)
plt.ylabel('Price' , fontsize = 20)
plt.plot(df.area , reg.predict(df[['area']]),color='blue')
plt.title('Per Capita Income in Canada Over Years')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']] , df.price)
# Out:
# LinearRegression()

# %%
X_new = pd.DataFrame({'area': [3300]})  # Example data
predicted_price = reg.predict(X_new)

# %%
predicted_price
# Out:
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# # y=m*x+c

# %%
y = 135.78767123*3300+180616.43835616432
y
# Out:
# 628715.7534151643

# %% [markdown]
# # Adding or we can say predicting prices of new csv file areas

# %%
d = pd.read_csv("areas.csv")

# %%
d.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p = reg.predict(d)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
d['prices'] = p
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
d.to_csv("prediction.csv" , index=False)

# %%
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %% [markdown]
# #  multi variable

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("multiVariable.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
import math
Median_B = math.floor(df.bedrooms.median())
Median_B
# Out:
# 4

# %%
df.bedrooms = df.bedrooms.fillna(Median_B)
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area' , 'bedrooms' , 'age']] , df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg.intercept_
# Out:
# 221323.00186540408

# %%
reg.predict([[3000 , 3 , 50]])
# Out:
# C:\Users\ys290\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([466091.07249398])
